# %% [markdown]
# # LangChain의 RAG 파헤치기
#
# ![rag-1.png](./assets/rag-1.png)
#
# ![rag-2.png](./assets/rag-2.png)
#
# ### 1. 질문 처리
#
# 질문 처리 단계에서는 사용자의 질문을 받아 이를 처리하고, 관련 데이터를 찾는 작업이 이루어집니다. 이를 위해 다음과 같은 구성 요소들이 필요합니다:
#
# - **데이터 소스 연결**: 질문에 대한 답변을 찾기 위해 다양한 텍스트 데이터 소스에 연결해야 합니다. LangChain은 다양한 데이터 소스와의 연결을 간편하게 설정할 수 있도록 돕습니다.
# - **데이터 인덱싱 및 검색**: 데이터 소스에서 관련 정보를 효율적으로 찾기 위해, 데이터는 인덱싱되어야 합니다. LangChain은 인덱싱 과정을 자동화하고, 사용자의 질문과 관련된 데이터를 검색하는 데 필요한 도구를 제공합니다.
#
# ### 2. 답변 생성
#
# 관련 데이터를 찾은 후에는 이를 기반으로 사용자의 질문에 답변을 생성해야 합니다. 이 단계에서는 다음 구성 요소가 중요합니다:
#
# - **답변 생성 모델**: LangChain은 고급 자연어 처리(NLP) 모델을 사용하여 검색된 데이터로부터 답변을 생성할 수 있는 기능을 제공합니다. 이러한 모델은 사용자의 질문과 검색된 데이터를 입력으로 받아, 적절한 답변을 생성합니다.

# %% [markdown]
# # RAG for KBO 2024
#
# 야구를 주제로 한 RAG(Retrieval-Augmented Generation) 시스템 구축 실습입니다.
# KBO 2025 레코드북과 연감 데이터를 사용하여 질문에 답변하는 시스템을 만들어 봅니다.

# %% [markdown]
# ## 1. 환경 설정
#
# API 키 등 필요한 환경 변수를 로드합니다.

# %%
from dotenv import load_dotenv
import os

# .env 파일에서 환경 변수 로드
load_dotenv()

# LangSmith 설정 (선택 사항)
# os.environ['LANGCHAIN_TRACING_V2'] = 'true'
# os.environ['LANGCHAIN_API_KEY'] = 'your-api-key'
# Out:
# True

# %% [markdown]
# ## 2. 문서 로드 (Load Documents)
#
# baseball 폴더에 있는 PDF 파일들을 로드합니다.

# %%
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader

# baseball 폴더 내의 모든 pdf 파일 로드
loader = DirectoryLoader("./baseball", glob="*.pdf", loader_cls=PyPDFLoader)
docs = loader.load()

print(f"총 {len(docs)} 페이지의 문서가 로드되었습니다.")
print(f"첫 번째 문서의 일부 내용:\n{docs[0].page_content[:200]}")
# Out:
# Ignoring wrong pointing object 2 65536 (offset 0)
# Ignoring wrong pointing object 9 65536 (offset 0)
# Ignoring wrong pointing object 16 65536 (offset 0)
# Ignoring wrong pointing object 39 65536 (offset 0)
# Ignoring wrong pointing object 45 65536 (offset 0)
# Ignoring wrong pointing object 93 65536 (offset 0)
# Ignoring wrong pointing object 120 65536 (offset 0)
# Ignoring wrong pointing object 136 65536 (offset 0)
# Ignoring wrong pointing object 143 65536 (offset 0)
# Ignoring wrong pointing object 168 65536 (offset 0)
# Ignoring wrong pointing object 174 65536 (offset 0)
# Ignoring wrong pointing object 200 65536 (offset 0)
# Ignoring wrong pointing object 206 65536 (offset 0)
# Ignoring wrong pointing object 212 65536 (offset 0)
# Ignoring wrong pointing object 225 65536 (offset 0)
# Ignoring wrong pointing object 231 65536 (offset 0)
# Ignoring wrong pointing object 237 65536 (offset 0)
# Ignoring wrong pointing object 256 65536 (offset 0)
# Ignoring wrong pointing object 280 65536 (offset 0)
# Ignoring wrong pointing object 286 65536 (offset 0)
# Ignoring wrong pointing object 298 65536 (offset 0)
# Ignoring wrong pointing object 304 65536 (offset 0)
# Ignoring wrong pointing object 311 65536 (offset 0)
# Ignoring wrong pointing object 322 65536 (offset 0)
# Ignoring wrong pointing object 328 65536 (offset 0)
# Ignoring wrong pointing object 334 65536 (offset 0)
# Ignoring wrong pointing object 341 65536 (offset 0)
# Ignoring wrong pointing object 347 65536 (offset 0)
# Ignoring wrong pointing object 353 65536 (offset 0)
# Ignoring wrong pointing object 359 65536 (offset 0)
# Ignoring wrong pointing object 366 65536 (offset 0)
# Ignoring wrong pointing object 372 65536 (offset 0)
# Ignoring wrong pointing object 378 65536 (offset 0)
# Ignoring wrong pointing object 384 65536 (offset 0)
# Ignoring wrong pointing object 391 65536 (offset 0)
# Ignoring wrong pointing object 397 65536 (offset 0)
# Ignoring wrong pointing object 403 65536 (offset 0)
# Ignoring wrong pointing object 409 65536 (offset 0)
# Ignoring wrong pointing object 416 65536 (offset 0)
# Ignoring wrong pointing object 422 65536 (offset 0)
# Ignoring wrong pointing object 428 65536 (offset 0)
# Ignoring wrong pointing object 434 65536 (offset 0)
# Ignoring wrong pointing object 441 65536 (offset 0)
# Ignoring wrong pointing object 447 65536 (offset 0)
# Ignoring wrong pointing object 453 65536 (offset 0)
# Ignoring wrong pointing object 459 65536 (offset 0)
# Ignoring wrong pointing object 465 65536 (offset 0)
# Ignoring wrong pointing object 472 65536 (offset 0)
# Ignoring wrong pointing object 478 65536 (offset 0)
# Ignoring wrong pointing object 484 65536 (offset 0)
# Ignoring wrong pointing object 490 65536 (offset 0)
# Ignoring wrong pointing object 497 65536 (offset 0)
# Ignoring wrong pointing object 503 65536 (offset 0)
# Ignoring wrong pointing object 509 65536 (offset 0)
# Ignoring wrong pointing object 515 65536 (offset 0)
# Ignoring wrong pointing object 522 65536 (offset 0)
# Ignoring wrong pointing object 528 65536 (offset 0)
# Ignoring wrong pointing object 534 65536 (offset 0)
# Ignoring wrong pointing object 540 65536 (offset 0)
# Ignoring wrong pointing object 556 65536 (offset 0)
# Ignoring wrong pointing object 573 65536 (offset 0)
# Ignoring wrong pointing object 579 65536 (offset 0)
# Ignoring wrong pointing object 603 65536 (offset 0)
# Ignoring wrong pointing object 609 65536 (offset 0)
# Ignoring wrong pointing object 615 65536 (offset 0)
# Ignoring wrong pointing object 621 65536 (offset 0)
# Ignoring wrong pointing object 627 65536 (offset 0)
# Ignoring wrong pointing object 633 65536 (offset 0)
# Ignoring wrong pointing object 639 65536 (offset 0)
# Ignoring wrong pointing object 649 65536 (offset 0)
# Ignoring wrong pointing object 655 65536 (offset 0)
# Ignoring wrong pointing object 661 65536 (offset 0)
# Ignoring wrong pointing object 667 65536 (offset 0)
# Ignoring wrong pointing object 673 65536 (offset 0)
# Ignoring wrong pointing object 679 65536 (offset 0)
# Ignoring wrong pointing object 685 65536 (offset 0)
# Ignoring wrong pointing object 691 65536 (offset 0)
# Ignoring wrong pointing object 697 65536 (offset 0)
# Ignoring wrong pointing object 712 65536 (offset 0)
# Ignoring wrong pointing object 718 65536 (offset 0)
# Ignoring wrong pointing object 724 65536 (offset 0)
# Ignoring wrong pointing object 730 65536 (offset 0)
# Ignoring wrong pointing object 745 65536 (offset 0)
# Ignoring wrong pointing object 751 65536 (offset 0)
# Ignoring wrong pointing object 757 65536 (offset 0)
# Ignoring wrong pointing object 763 65536 (offset 0)
# Ignoring wrong pointing object 769 65536 (offset 0)
# Ignoring wrong pointing object 775 65536 (offset 0)
# Ignoring wrong pointing object 781 65536 (offset 0)
# Ignoring wrong pointing object 787 65536 (offset 0)
# Ignoring wrong pointing object 793 65536 (offset 0)
# Ignoring wrong pointing object 799 65536 (offset 0)
# Ignoring wrong pointing object 805 65536 (offset 0)
# Ignoring wrong pointing object 811 65536 (offset 0)
# Ignoring wrong pointing object 817 65536 (offset 0)
# Ignoring wrong pointing object 823 65536 (offset 0)
# Ignoring wrong pointing object 829 65536 (offset 0)
# Ignoring wrong pointing object 835 65536 (offset 0)
# Ignoring wrong pointing object 850 65536 (offset 0)
# Ignoring wrong pointing object 882 65536 (offset 0)
# Ignoring wrong pointing object 888 65536 (offset 0)
# Ignoring wrong pointing object 903 65536 (offset 0)
# Ignoring wrong pointing object 909 65536 (offset 0)
# Ignoring wrong pointing object 924 65536 (offset 0)
# Ignoring wrong pointing object 930 65536 (offset 0)
# Ignoring wrong pointing object 950 65536 (offset 0)
# Ignoring wrong pointing object 963 65536 (offset 0)
# Ignoring wrong pointing object 969 65536 (offset 0)
# Ignoring wrong pointing object 975 65536 (offset 0)
# Ignoring wrong pointing object 981 65536 (offset 0)
# Ignoring wrong pointing object 987 65536 (offset 0)
# Ignoring wrong pointing object 993 65536 (offset 0)
# Ignoring wrong pointing object 999 65536 (offset 0)
# Ignoring wrong pointing object 1005 65536 (offset 0)
# Ignoring wrong pointing object 1020 65536 (offset 0)
# Ignoring wrong pointing object 1026 65536 (offset 0)
# Ignoring wrong pointing object 1041 65536 (offset 0)
# Ignoring wrong pointing object 1047 65536 (offset 0)
# Ignoring wrong pointing object 1053 65536 (offset 0)
# Ignoring wrong pointing object 1070 65536 (offset 0)
# Ignoring wrong pointing object 1077 65536 (offset 0)
# Ignoring wrong pointing object 1084 65536 (offset 0)
# Ignoring wrong pointing object 1101 65536 (offset 0)
# Ignoring wrong pointing object 1107 65536 (offset 0)
# Ignoring wrong pointing object 1124 65536 (offset 0)
# Ignoring wrong pointing object 1130 65536 (offset 0)
# Ignoring wrong pointing object 1136 65536 (offset 0)
# Ignoring wrong pointing object 1142 65536 (offset 0)
# Ignoring wrong pointing object 1148 65536 (offset 0)
# Ignoring wrong pointing object 1154 65536 (offset 0)
# Ignoring wrong pointing object 1160 65536 (offset 0)
# Ignoring wrong pointing object 1166 65536 (offset 0)
# Ignoring wrong pointing object 1172 65536 (offset 0)
# Ignoring wrong pointing object 1178 65536 (offset 0)
# Ignoring wrong pointing object 1184 65536 (offset 0)
# Ignoring wrong pointing object 1190 65536 (offset 0)
# Ignoring wrong pointing object 1196 65536 (offset 0)
# Ignoring wrong pointing object 1202 65536 (offset 0)
# Ignoring wrong pointing object 1208 65536 (offset 0)
# Ignoring wrong pointing object 1214 65536 (offset 0)
# Ignoring wrong pointing object 1220 65536 (offset 0)
# Ignoring wrong pointing object 1226 65536 (offset 0)
# Ignoring wrong pointing object 1232 65536 (offset 0)
# Ignoring wrong pointing object 1238 65536 (offset 0)
# Ignoring wrong pointing object 1244 65536 (offset 0)
# Ignoring wrong pointing object 1250 65536 (offset 0)
# Ignoring wrong pointing object 1256 65536 (offset 0)
# Ignoring wrong pointing object 1262 65536 (offset 0)
# Ignoring wrong pointing object 1268 65536 (offset 0)
# Ignoring wrong pointing object 1274 65536 (offset 0)
# Ignoring wrong pointing object 1280 65536 (offset 0)
# Ignoring wrong pointing object 1286 65536 (offset 0)
# Ignoring wrong pointing object 1292 65536 (offset 0)
# Ignoring wrong pointing object 1298 65536 (offset 0)
# Ignoring wrong pointing object 1304 65536 (offset 0)
# Ignoring wrong pointing object 1310 65536 (offset 0)
# Ignoring wrong pointing object 1316 65536 (offset 0)
# Ignoring wrong pointing object 1322 65536 (offset 0)
# Ignoring wrong pointing object 1337 65536 (offset 0)
# Ignoring wrong pointing object 1343 65536 (offset 0)
# Ignoring wrong pointing object 1356 65536 (offset 0)
# Ignoring wrong pointing object 1363 65536 (offset 0)
# Ignoring wrong pointing object 1380 65536 (offset 0)
# Ignoring wrong pointing object 1387 65536 (offset 0)
# Ignoring wrong pointing object 1404 65536 (offset 0)
# Ignoring wrong pointing object 1419 65536 (offset 0)
# Ignoring wrong pointing object 1425 65536 (offset 0)
# Ignoring wrong pointing object 1431 65536 (offset 0)
# Ignoring wrong pointing object 1437 65536 (offset 0)
# Ignoring wrong pointing object 1443 65536 (offset 0)
# Ignoring wrong pointing object 1449 65536 (offset 0)
# Ignoring wrong pointing object 1455 65536 (offset 0)
# Ignoring wrong pointing object 1461 65536 (offset 0)
# Ignoring wrong pointing object 1467 65536 (offset 0)
# Ignoring wrong pointing object 1473 65536 (offset 0)
# Ignoring wrong pointing object 1491 65536 (offset 0)
# Ignoring wrong pointing object 1504 65536 (offset 0)
# Ignoring wrong pointing object 1513 65536 (offset 0)
# Ignoring wrong pointing object 1520 65536 (offset 0)
# Ignoring wrong pointing object 1527 65536 (offset 0)
# Ignoring wrong pointing object 1534 65536 (offset 0)
# Ignoring wrong pointing object 1541 65536 (offset 0)
# Ignoring wrong pointing object 1548 65536 (offset 0)
# Ignoring wrong pointing object 1565 65536 (offset 0)
# Ignoring wrong pointing object 1571 65536 (offset 0)
# Ignoring wrong pointing object 1577 65536 (offset 0)
# Ignoring wrong pointing object 1583 65536 (offset 0)
# Ignoring wrong pointing object 1589 65536 (offset 0)
# Ignoring wrong pointing object 1595 65536 (offset 0)
# Ignoring wrong pointing object 1601 65536 (offset 0)
# Ignoring wrong pointing object 1607 65536 (offset 0)
# Ignoring wrong pointing object 1613 65536 (offset 0)
# Ignoring wrong pointing object 1619 65536 (offset 0)
# Ignoring wrong pointing object 1636 65536 (offset 0)
# Ignoring wrong pointing object 1651 65536 (offset 0)
# Ignoring wrong pointing object 1657 65536 (offset 0)
# Ignoring wrong pointing object 1663 65536 (offset 0)
# Ignoring wrong pointing object 1669 65536 (offset 0)
# Ignoring wrong pointing object 1675 65536 (offset 0)
# Ignoring wrong pointing object 1681 65536 (offset 0)
# Ignoring wrong pointing object 1687 65536 (offset 0)
# Ignoring wrong pointing object 1693 65536 (offset 0)
# Ignoring wrong pointing object 1699 65536 (offset 0)
# Ignoring wrong pointing object 1718 65536 (offset 0)
# Ignoring wrong pointing object 1724 65536 (offset 0)
# Ignoring wrong pointing object 1741 65536 (offset 0)
# Ignoring wrong pointing object 1747 65536 (offset 0)
# Ignoring wrong pointing object 1753 65536 (offset 0)
# Ignoring wrong pointing object 1759 65536 (offset 0)
# Ignoring wrong pointing object 1765 65536 (offset 0)
# Ignoring wrong pointing object 1771 65536 (offset 0)
# Ignoring wrong pointing object 1777 65536 (offset 0)
# Ignoring wrong pointing object 1783 65536 (offset 0)
# Ignoring wrong pointing object 1800 65536 (offset 0)
# Ignoring wrong pointing object 1806 65536 (offset 0)
# Ignoring wrong pointing object 1812 65536 (offset 0)
# Ignoring wrong pointing object 1818 65536 (offset 0)
# Ignoring wrong pointing object 1824 65536 (offset 0)
# Ignoring wrong pointing object 1830 65536 (offset 0)
# Ignoring wrong pointing object 1836 65536 (offset 0)
# Ignoring wrong pointing object 1842 65536 (offset 0)
# Ignoring wrong pointing object 1848 65536 (offset 0)
# Ignoring wrong pointing object 1865 65536 (offset 0)
# Ignoring wrong pointing object 1871 65536 (offset 0)
# Ignoring wrong pointing object 1877 65536 (offset 0)
# Ignoring wrong pointing object 1883 65536 (offset 0)
# Ignoring wrong pointing object 1891 65536 (offset 0)
# Ignoring wrong pointing object 1897 65536 (offset 0)
# Ignoring wrong pointing object 1903 65536 (offset 0)
# Ignoring wrong pointing object 1909 65536 (offset 0)
# Ignoring wrong pointing object 1915 65536 (offset 0)
# Ignoring wrong pointing object 1921 65536 (offset 0)
# Ignoring wrong pointing object 1927 65536 (offset 0)
# Ignoring wrong pointing object 1933 65536 (offset 0)
# Ignoring wrong pointing object 1939 65536 (offset 0)
# Ignoring wrong pointing object 1945 65536 (offset 0)
# Ignoring wrong pointing object 1951 65536 (offset 0)
# Ignoring wrong pointing object 1957 65536 (offset 0)
# Ignoring wrong pointing object 1963 65536 (offset 0)
# Ignoring wrong pointing object 1969 65536 (offset 0)
# Ignoring wrong pointing object 1975 65536 (offset 0)
# Ignoring wrong pointing object 1981 65536 (offset 0)
# Ignoring wrong pointing object 1987 65536 (offset 0)
# Ignoring wrong pointing object 1993 65536 (offset 0)
# Ignoring wrong pointing object 1999 65536 (offset 0)
# Ignoring wrong pointing object 2005 65536 (offset 0)
# Ignoring wrong pointing object 2011 65536 (offset 0)
# Ignoring wrong pointing object 2017 65536 (offset 0)
# Ignoring wrong pointing object 2023 65536 (offset 0)
# Ignoring wrong pointing object 2029 65536 (offset 0)
# Ignoring wrong pointing object 2035 65536 (offset 0)
# Ignoring wrong pointing object 2041 65536 (offset 0)
# Ignoring wrong pointing object 2047 65536 (offset 0)
# Ignoring wrong pointing object 2053 65536 (offset 0)
# Ignoring wrong pointing object 2059 65536 (offset 0)
# Ignoring wrong pointing object 2065 65536 (offset 0)
# Ignoring wrong pointing object 2071 65536 (offset 0)
# Ignoring wrong pointing object 2077 65536 (offset 0)
# Ignoring wrong pointing object 2083 65536 (offset 0)
# Ignoring wrong pointing object 2089 65536 (offset 0)
# Ignoring wrong pointing object 2095 65536 (offset 0)
# Ignoring wrong pointing object 2101 65536 (offset 0)
# Ignoring wrong pointing object 2107 65536 (offset 0)
# Ignoring wrong pointing object 2113 65536 (offset 0)
# Ignoring wrong pointing object 2119 65536 (offset 0)
# Ignoring wrong pointing object 2125 65536 (offset 0)
# Ignoring wrong pointing object 2131 65536 (offset 0)
# Ignoring wrong pointing object 2137 65536 (offset 0)
# Ignoring wrong pointing object 2143 65536 (offset 0)
# Ignoring wrong pointing object 2149 65536 (offset 0)
# Ignoring wrong pointing object 2155 65536 (offset 0)
# Ignoring wrong pointing object 2161 65536 (offset 0)
# Ignoring wrong pointing object 2167 65536 (offset 0)
# Ignoring wrong pointing object 2173 65536 (offset 0)
# Ignoring wrong pointing object 2179 65536 (offset 0)
# Ignoring wrong pointing object 2185 65536 (offset 0)
# Ignoring wrong pointing object 2191 65536 (offset 0)
# Ignoring wrong pointing object 2197 65536 (offset 0)
# Ignoring wrong pointing object 2203 65536 (offset 0)
# Ignoring wrong pointing object 2209 65536 (offset 0)
# Ignoring wrong pointing object 2215 65536 (offset 0)
# Ignoring wrong pointing object 2234 65536 (offset 0)
# Ignoring wrong pointing object 2240 65536 (offset 0)
# Ignoring wrong pointing object 2246 65536 (offset 0)
# Ignoring wrong pointing object 2252 65536 (offset 0)
# Ignoring wrong pointing object 2258 65536 (offset 0)
# Ignoring wrong pointing object 2264 65536 (offset 0)
# Ignoring wrong pointing object 2270 65536 (offset 0)
# Ignoring wrong pointing object 2276 65536 (offset 0)
# Ignoring wrong pointing object 2282 65536 (offset 0)
# Ignoring wrong pointing object 2288 65536 (offset 0)
# Ignoring wrong pointing object 2294 65536 (offset 0)
# Ignoring wrong pointing object 2300 65536 (offset 0)
# Ignoring wrong pointing object 2306 65536 (offset 0)
# Ignoring wrong pointing object 2312 65536 (offset 0)
# Ignoring wrong pointing object 2318 65536 (offset 0)
# Ignoring wrong pointing object 2324 65536 (offset 0)
# Ignoring wrong pointing object 2330 65536 (offset 0)
# Ignoring wrong pointing object 2336 65536 (offset 0)
# Ignoring wrong pointing object 2351 65536 (offset 0)
# Ignoring wrong pointing object 2357 65536 (offset 0)
# Ignoring wrong pointing object 2363 65536 (offset 0)
# Ignoring wrong pointing object 2384 65536 (offset 0)
# Ignoring wrong pointing object 2390 65536 (offset 0)
# Ignoring wrong pointing object 2396 65536 (offset 0)
# Ignoring wrong pointing object 2402 65536 (offset 0)
# Ignoring wrong pointing object 2408 65536 (offset 0)
# Ignoring wrong pointing object 2414 65536 (offset 0)
# Ignoring wrong pointing object 2420 65536 (offset 0)
# Ignoring wrong pointing object 2426 65536 (offset 0)
# Ignoring wrong pointing object 2432 65536 (offset 0)
# Ignoring wrong pointing object 2438 65536 (offset 0)
# Ignoring wrong pointing object 2444 65536 (offset 0)
# Ignoring wrong pointing object 2450 65536 (offset 0)
# Ignoring wrong pointing object 2456 65536 (offset 0)
# Ignoring wrong pointing object 2462 65536 (offset 0)
# Ignoring wrong pointing object 2468 65536 (offset 0)
# Ignoring wrong pointing object 2474 65536 (offset 0)
# Ignoring wrong pointing object 2480 65536 (offset 0)
# Ignoring wrong pointing object 2486 65536 (offset 0)
# Ignoring wrong pointing object 2492 65536 (offset 0)
# Ignoring wrong pointing object 2498 65536 (offset 0)
# Ignoring wrong pointing object 2504 65536 (offset 0)
# Ignoring wrong pointing object 2510 65536 (offset 0)
# Ignoring wrong pointing object 2516 65536 (offset 0)
# Ignoring wrong pointing object 2522 65536 (offset 0)
# Ignoring wrong pointing object 2528 65536 (offset 0)
# Ignoring wrong pointing object 2534 65536 (offset 0)
# Ignoring wrong pointing object 2540 65536 (offset 0)
# Ignoring wrong pointing object 2546 65536 (offset 0)
# Ignoring wrong pointing object 2552 65536 (offset 0)
# Ignoring wrong pointing object 2558 65536 (offset 0)
# Ignoring wrong pointing object 2564 65536 (offset 0)
# Ignoring wrong pointing object 2570 65536 (offset 0)
# Ignoring wrong pointing object 2576 65536 (offset 0)
# Ignoring wrong pointing object 2582 65536 (offset 0)
# Ignoring wrong pointing object 2588 65536 (offset 0)
# Ignoring wrong pointing object 2594 65536 (offset 0)
# Ignoring wrong pointing object 2600 65536 (offset 0)
# Ignoring wrong pointing object 2606 65536 (offset 0)
# Ignoring wrong pointing object 2612 65536 (offset 0)
# Ignoring wrong pointing object 2618 65536 (offset 0)
# Ignoring wrong pointing object 2637 65536 (offset 0)
# Ignoring wrong pointing object 2643 65536 (offset 0)
# Ignoring wrong pointing object 2649 65536 (offset 0)
# Ignoring wrong pointing object 2655 65536 (offset 0)
# Ignoring wrong pointing object 2661 65536 (offset 0)
# Ignoring wrong pointing object 2667 65536 (offset 0)
# Ignoring wrong pointing object 2673 65536 (offset 0)
# Ignoring wrong pointing object 2679 65536 (offset 0)
# Ignoring wrong pointing object 2685 65536 (offset 0)
# Ignoring wrong pointing object 2691 65536 (offset 0)
# Ignoring wrong pointing object 2697 65536 (offset 0)
# Ignoring wrong pointing object 2703 65536 (offset 0)
# Ignoring wrong pointing object 2724 65536 (offset 0)
# Ignoring wrong pointing object 2741 65536 (offset 0)
# Ignoring wrong pointing object 2747 65536 (offset 0)
# Ignoring wrong pointing object 2753 65536 (offset 0)
# Ignoring wrong pointing object 2759 65536 (offset 0)
# Ignoring wrong pointing object 2777 65536 (offset 0)
# Ignoring wrong pointing object 2783 65536 (offset 0)
# Ignoring wrong pointing object 2798 65536 (offset 0)
# Ignoring wrong pointing object 2804 65536 (offset 0)
# Ignoring wrong pointing object 2810 65536 (offset 0)
# Ignoring wrong pointing object 2816 65536 (offset 0)
# Ignoring wrong pointing object 2822 65536 (offset 0)
# Ignoring wrong pointing object 2828 65536 (offset 0)
# Ignoring wrong pointing object 2845 65536 (offset 0)
# Ignoring wrong pointing object 2857 65536 (offset 0)
# Ignoring wrong pointing object 2863 65536 (offset 0)
# Ignoring wrong pointing object 2869 65536 (offset 0)
# Ignoring wrong pointing object 2887 65536 (offset 0)
# Ignoring wrong pointing object 2893 65536 (offset 0)
# Ignoring wrong pointing object 2899 65536 (offset 0)
# Ignoring wrong pointing object 2905 65536 (offset 0)
# Ignoring wrong pointing object 2911 65536 (offset 0)
# Ignoring wrong pointing object 2919 65536 (offset 0)
# Ignoring wrong pointing object 2925 65536 (offset 0)
# Ignoring wrong pointing object 2931 65536 (offset 0)
# Ignoring wrong pointing object 2937 65536 (offset 0)
# Ignoring wrong pointing object 2943 65536 (offset 0)
# Ignoring wrong pointing object 2951 65536 (offset 0)
# Ignoring wrong pointing object 2972 65536 (offset 0)
# Ignoring wrong pointing object 2978 65536 (offset 0)
# Ignoring wrong pointing object 2984 65536 (offset 0)
# Ignoring wrong pointing object 2990 65536 (offset 0)
# Ignoring wrong pointing object 2996 65536 (offset 0)
# Ignoring wrong pointing object 3002 65536 (offset 0)
# Ignoring wrong pointing object 3008 65536 (offset 0)
# Ignoring wrong pointing object 3014 65536 (offset 0)
# Ignoring wrong pointing object 3020 65536 (offset 0)
# Ignoring wrong pointing object 3026 65536 (offset 0)
# Ignoring wrong pointing object 3032 65536 (offset 0)
# Ignoring wrong pointing object 3038 65536 (offset 0)
# Ignoring wrong pointing object 3044 65536 (offset 0)
# Ignoring wrong pointing object 3060 65536 (offset 0)
# Ignoring wrong pointing object 3072 65536 (offset 0)
# Ignoring wrong pointing object 3078 65536 (offset 0)
# Ignoring wrong pointing object 3090 65536 (offset 0)
# Ignoring wrong pointing object 3096 65536 (offset 0)
# Ignoring wrong pointing object 3102 65536 (offset 0)
# Ignoring wrong pointing object 3123 65536 (offset 0)
# Ignoring wrong pointing object 3129 65536 (offset 0)
# Ignoring wrong pointing object 3135 65536 (offset 0)
# Ignoring wrong pointing object 3141 65536 (offset 0)
# Ignoring wrong pointing object 3147 65536 (offset 0)
# Ignoring wrong pointing object 3153 65536 (offset 0)
# Ignoring wrong pointing object 3159 65536 (offset 0)
# Ignoring wrong pointing object 3165 65536 (offset 0)
# Ignoring wrong pointing object 3171 65536 (offset 0)
# Ignoring wrong pointing object 3177 65536 (offset 0)
# Ignoring wrong pointing object 3183 65536 (offset 0)
# Ignoring wrong pointing object 3189 65536 (offset 0)
# Ignoring wrong pointing object 3195 65536 (offset 0)
# Ignoring wrong pointing object 3201 65536 (offset 0)
# Ignoring wrong pointing object 3217 65536 (offset 0)
# Ignoring wrong pointing object 3229 65536 (offset 0)
# Ignoring wrong pointing object 3241 65536 (offset 0)
# Ignoring wrong pointing object 3247 65536 (offset 0)
# Ignoring wrong pointing object 3253 65536 (offset 0)
# Ignoring wrong pointing object 3259 65536 (offset 0)
# Ignoring wrong pointing object 3265 65536 (offset 0)
# Ignoring wrong pointing object 3271 65536 (offset 0)
# Ignoring wrong pointing object 3277 65536 (offset 0)
# Ignoring wrong pointing object 3298 65536 (offset 0)
# Ignoring wrong pointing object 3304 65536 (offset 0)
# Ignoring wrong pointing object 3310 65536 (offset 0)
# Ignoring wrong pointing object 3316 65536 (offset 0)
# Ignoring wrong pointing object 3322 65536 (offset 0)
# Ignoring wrong pointing object 3328 65536 (offset 0)
# Ignoring wrong pointing object 3334 65536 (offset 0)
# Ignoring wrong pointing object 3340 65536 (offset 0)
# Ignoring wrong pointing object 3346 65536 (offset 0)
# Ignoring wrong pointing object 3352 65536 (offset 0)
# Ignoring wrong pointing object 3358 65536 (offset 0)
# Ignoring wrong pointing object 3364 65536 (offset 0)
# Ignoring wrong pointing object 3370 65536 (offset 0)
# Ignoring wrong pointing object 3376 65536 (offset 0)
# Ignoring wrong pointing object 3382 65536 (offset 0)
# Ignoring wrong pointing object 3388 65536 (offset 0)
# Ignoring wrong pointing object 3413 65536 (offset 0)
# Ignoring wrong pointing object 3428 65536 (offset 0)
# Ignoring wrong pointing object 3446 65536 (offset 0)
# Ignoring wrong pointing object 3459 65536 (offset 0)
# Ignoring wrong pointing object 3465 65536 (offset 0)
# Ignoring wrong pointing object 3471 65536 (offset 0)
# Ignoring wrong pointing object 3477 65536 (offset 0)
# Ignoring wrong pointing object 3498 65536 (offset 0)
# Ignoring wrong pointing object 3504 65536 (offset 0)
# Ignoring wrong pointing object 3510 65536 (offset 0)
# Ignoring wrong pointing object 3516 65536 (offset 0)
# Ignoring wrong pointing object 3522 65536 (offset 0)
# Ignoring wrong pointing object 3528 65536 (offset 0)
# Ignoring wrong pointing object 3534 65536 (offset 0)
# Ignoring wrong pointing object 3540 65536 (offset 0)
# Ignoring wrong pointing object 3546 65536 (offset 0)
# Ignoring wrong pointing object 3552 65536 (offset 0)
# Ignoring wrong pointing object 3558 65536 (offset 0)
# Ignoring wrong pointing object 3564 65536 (offset 0)
# Ignoring wrong pointing object 3570 65536 (offset 0)
# Ignoring wrong pointing object 3576 65536 (offset 0)
# Ignoring wrong pointing object 3582 65536 (offset 0)
# Ignoring wrong pointing object 3588 65536 (offset 0)
# Ignoring wrong pointing object 3594 65536 (offset 0)
# Ignoring wrong pointing object 3610 65536 (offset 0)
# Ignoring wrong pointing object 3622 65536 (offset 0)
# Ignoring wrong pointing object 3634 65536 (offset 0)
# Ignoring wrong pointing object 3640 65536 (offset 0)
# Ignoring wrong pointing object 3646 65536 (offset 0)
# Ignoring wrong pointing object 3652 65536 (offset 0)
# Ignoring wrong pointing object 3658 65536 (offset 0)
# Ignoring wrong pointing object 3664 65536 (offset 0)
# Ignoring wrong pointing object 3685 65536 (offset 0)
# Ignoring wrong pointing object 3691 65536 (offset 0)
# Ignoring wrong pointing object 3697 65536 (offset 0)
# Ignoring wrong pointing object 3703 65536 (offset 0)
# Ignoring wrong pointing object 3709 65536 (offset 0)
# Ignoring wrong pointing object 3715 65536 (offset 0)
# Ignoring wrong pointing object 3721 65536 (offset 0)
# Ignoring wrong pointing object 3727 65536 (offset 0)
# Ignoring wrong pointing object 3733 65536 (offset 0)
# Ignoring wrong pointing object 3739 65536 (offset 0)
# Ignoring wrong pointing object 3745 65536 (offset 0)
# Ignoring wrong pointing object 3751 65536 (offset 0)
# Ignoring wrong pointing object 3757 65536 (offset 0)
# Ignoring wrong pointing object 3763 65536 (offset 0)
# Ignoring wrong pointing object 3769 65536 (offset 0)
# Ignoring wrong pointing object 3775 65536 (offset 0)
# Ignoring wrong pointing object 3781 65536 (offset 0)
# Ignoring wrong pointing object 3799 65536 (offset 0)
# Ignoring wrong pointing object 3805 65536 (offset 0)
# Ignoring wrong pointing object 3820 65536 (offset 0)
# Ignoring wrong pointing object 3835 65536 (offset 0)
# Ignoring wrong pointing object 3842 65536 (offset 0)
# Ignoring wrong pointing object 3849 65536 (offset 0)
# Ignoring wrong pointing object 3864 65536 (offset 0)
# Ignoring wrong pointing object 3879 65536 (offset 0)
# Ignoring wrong pointing object 3886 65536 (offset 0)
# Ignoring wrong pointing object 3893 65536 (offset 0)
# Ignoring wrong pointing object 3900 65536 (offset 0)
# Ignoring wrong pointing object 3907 65536 (offset 0)
# Ignoring wrong pointing object 3914 65536 (offset 0)
# Ignoring wrong pointing object 3921 65536 (offset 0)
# Ignoring wrong pointing object 3928 65536 (offset 0)
# Ignoring wrong pointing object 3935 65536 (offset 0)
# Ignoring wrong pointing object 3950 65536 (offset 0)
# Ignoring wrong pointing object 3963 65536 (offset 0)
# Ignoring wrong pointing object 3971 65536 (offset 0)
# Ignoring wrong pointing object 3977 65536 (offset 0)
# Ignoring wrong pointing object 3985 65536 (offset 0)
# Ignoring wrong pointing object 3991 65536 (offset 0)
# Ignoring wrong pointing object 3997 65536 (offset 0)
# Ignoring wrong pointing object 4003 65536 (offset 0)
# Ignoring wrong pointing object 4009 65536 (offset 0)
# Ignoring wrong pointing object 4015 65536 (offset 0)
# Ignoring wrong pointing object 4021 65536 (offset 0)
# Ignoring wrong pointing object 4027 65536 (offset 0)
# Ignoring wrong pointing object 4033 65536 (offset 0)
# Ignoring wrong pointing object 4039 65536 (offset 0)
# Ignoring wrong pointing object 4045 65536 (offset 0)
# Ignoring wrong pointing object 4057 65536 (offset 0)
# Ignoring wrong pointing object 4072 65536 (offset 0)
# Ignoring wrong pointing object 4078 65536 (offset 0)
# Ignoring wrong pointing object 4085 65536 (offset 0)
# Advanced encoding /KSC-EUC-H not implemented yet
# Advanced encoding /KSC-EUC-H not implemented yet
# Advanced encoding /KSC-EUC-H not implemented yet
# Advanced encoding /KSC-EUC-H not implemented yet
# Ignoring wrong pointing object 2 65536 (offset 0)
# Ignoring wrong pointing object 9 65536 (offset 0)
# Ignoring wrong pointing object 16 65536 (offset 0)
# Ignoring wrong pointing object 23 65536 (offset 0)
# Ignoring wrong pointing object 64 65536 (offset 0)
# Ignoring wrong pointing object 68 65536 (offset 0)
# Ignoring wrong pointing object 72 65536 (offset 0)
# Ignoring wrong pointing object 76 65536 (offset 0)
# Ignoring wrong pointing object 80 65536 (offset 0)
# Ignoring wrong pointing object 84 65536 (offset 0)
# Ignoring wrong pointing object 88 65536 (offset 0)
# Ignoring wrong pointing object 104 65536 (offset 0)
# Ignoring wrong pointing object 126 65536 (offset 0)
# Ignoring wrong pointing object 130 65536 (offset 0)
# Ignoring wrong pointing object 140 65536 (offset 0)
# Ignoring wrong pointing object 144 65536 (offset 0)
# Ignoring wrong pointing object 148 65536 (offset 0)
# Ignoring wrong pointing object 152 65536 (offset 0)
# Ignoring wrong pointing object 156 65536 (offset 0)
# Ignoring wrong pointing object 160 65536 (offset 0)
# Ignoring wrong pointing object 164 65536 (offset 0)
# Ignoring wrong pointing object 168 65536 (offset 0)
# Ignoring wrong pointing object 172 65536 (offset 0)
# Ignoring wrong pointing object 176 65536 (offset 0)
# Ignoring wrong pointing object 180 65536 (offset 0)
# Ignoring wrong pointing object 184 65536 (offset 0)
# Ignoring wrong pointing object 193 65536 (offset 0)
# Ignoring wrong pointing object 208 65536 (offset 0)
# Ignoring wrong pointing object 211 65536 (offset 0)
# Ignoring wrong pointing object 215 65536 (offset 0)
# Ignoring wrong pointing object 219 65536 (offset 0)
# Ignoring wrong pointing object 223 65536 (offset 0)
# Ignoring wrong pointing object 227 65536 (offset 0)
# Ignoring wrong pointing object 231 65536 (offset 0)
# Ignoring wrong pointing object 235 65536 (offset 0)
# Ignoring wrong pointing object 239 65536 (offset 0)
# Ignoring wrong pointing object 243 65536 (offset 0)
# Ignoring wrong pointing object 247 65536 (offset 0)
# Ignoring wrong pointing object 251 65536 (offset 0)
# Ignoring wrong pointing object 255 65536 (offset 0)
# Ignoring wrong pointing object 259 65536 (offset 0)
# Ignoring wrong pointing object 263 65536 (offset 0)
# Ignoring wrong pointing object 267 65536 (offset 0)
# Ignoring wrong pointing object 271 65536 (offset 0)
# Ignoring wrong pointing object 275 65536 (offset 0)
# Ignoring wrong pointing object 279 65536 (offset 0)
# Ignoring wrong pointing object 283 65536 (offset 0)
# Ignoring wrong pointing object 287 65536 (offset 0)
# Ignoring wrong pointing object 291 65536 (offset 0)
# Ignoring wrong pointing object 295 65536 (offset 0)
# Ignoring wrong pointing object 299 65536 (offset 0)
# Ignoring wrong pointing object 303 65536 (offset 0)
# Ignoring wrong pointing object 307 65536 (offset 0)
# Ignoring wrong pointing object 311 65536 (offset 0)
# Ignoring wrong pointing object 315 65536 (offset 0)
# Ignoring wrong pointing object 319 65536 (offset 0)
# Ignoring wrong pointing object 323 65536 (offset 0)
# Ignoring wrong pointing object 327 65536 (offset 0)
# Ignoring wrong pointing object 331 65536 (offset 0)
# Ignoring wrong pointing object 335 65536 (offset 0)
# Ignoring wrong pointing object 339 65536 (offset 0)
# Ignoring wrong pointing object 343 65536 (offset 0)
# Ignoring wrong pointing object 347 65536 (offset 0)
# Ignoring wrong pointing object 351 65536 (offset 0)
# Ignoring wrong pointing object 355 65536 (offset 0)
# Ignoring wrong pointing object 359 65536 (offset 0)
# Ignoring wrong pointing object 363 65536 (offset 0)
# Ignoring wrong pointing object 367 65536 (offset 0)
# Ignoring wrong pointing object 371 65536 (offset 0)
# Ignoring wrong pointing object 375 65536 (offset 0)
# Ignoring wrong pointing object 379 65536 (offset 0)
# Ignoring wrong pointing object 383 65536 (offset 0)
# Ignoring wrong pointing object 394 65536 (offset 0)
# Ignoring wrong pointing object 398 65536 (offset 0)
# Ignoring wrong pointing object 402 65536 (offset 0)
# Ignoring wrong pointing object 406 65536 (offset 0)
# Ignoring wrong pointing object 410 65536 (offset 0)
# Ignoring wrong pointing object 415 65536 (offset 0)
# Ignoring wrong pointing object 419 65536 (offset 0)
# Ignoring wrong pointing object 423 65536 (offset 0)
# Ignoring wrong pointing object 427 65536 (offset 0)
# Ignoring wrong pointing object 431 65536 (offset 0)
# Ignoring wrong pointing object 436 65536 (offset 0)
# Ignoring wrong pointing object 441 65536 (offset 0)
# Ignoring wrong pointing object 445 65536 (offset 0)
# Ignoring wrong pointing object 449 65536 (offset 0)
# Ignoring wrong pointing object 453 65536 (offset 0)
# Ignoring wrong pointing object 457 65536 (offset 0)
# Ignoring wrong pointing object 462 65536 (offset 0)
# Ignoring wrong pointing object 466 65536 (offset 0)
# Ignoring wrong pointing object 470 65536 (offset 0)
# Ignoring wrong pointing object 474 65536 (offset 0)
# Ignoring wrong pointing object 478 65536 (offset 0)
# Ignoring wrong pointing object 482 65536 (offset 0)
# Ignoring wrong pointing object 486 65536 (offset 0)
# Ignoring wrong pointing object 490 65536 (offset 0)
# Ignoring wrong pointing object 494 65536 (offset 0)
# Ignoring wrong pointing object 498 65536 (offset 0)
# Ignoring wrong pointing object 502 65536 (offset 0)
# Ignoring wrong pointing object 506 65536 (offset 0)
# Ignoring wrong pointing object 510 65536 (offset 0)
# Ignoring wrong pointing object 514 65536 (offset 0)
# Ignoring wrong pointing object 518 65536 (offset 0)
# Ignoring wrong pointing object 522 65536 (offset 0)
# Ignoring wrong pointing object 526 65536 (offset 0)
# Ignoring wrong pointing object 531 65536 (offset 0)
# Ignoring wrong pointing object 536 65536 (offset 0)
# Ignoring wrong pointing object 540 65536 (offset 0)
# Ignoring wrong pointing object 544 65536 (offset 0)
# Ignoring wrong pointing object 548 65536 (offset 0)
# Ignoring wrong pointing object 553 65536 (offset 0)
# Ignoring wrong pointing object 557 65536 (offset 0)
# Ignoring wrong pointing object 563 65536 (offset 0)
# Ignoring wrong pointing object 567 65536 (offset 0)
# Ignoring wrong pointing object 572 65536 (offset 0)
# Ignoring wrong pointing object 576 65536 (offset 0)
# Ignoring wrong pointing object 580 65536 (offset 0)
# Ignoring wrong pointing object 584 65536 (offset 0)
# Ignoring wrong pointing object 588 65536 (offset 0)
# Ignoring wrong pointing object 592 65536 (offset 0)
# Ignoring wrong pointing object 596 65536 (offset 0)
# Ignoring wrong pointing object 600 65536 (offset 0)
# Ignoring wrong pointing object 604 65536 (offset 0)
# Ignoring wrong pointing object 609 65536 (offset 0)
# Ignoring wrong pointing object 613 65536 (offset 0)
# Ignoring wrong pointing object 617 65536 (offset 0)
# Ignoring wrong pointing object 621 65536 (offset 0)
# Ignoring wrong pointing object 625 65536 (offset 0)
# Ignoring wrong pointing object 629 65536 (offset 0)
# Ignoring wrong pointing object 633 65536 (offset 0)
# Ignoring wrong pointing object 637 65536 (offset 0)
# Ignoring wrong pointing object 646 65536 (offset 0)
# Ignoring wrong pointing object 650 65536 (offset 0)
# Ignoring wrong pointing object 654 65536 (offset 0)
# Ignoring wrong pointing object 658 65536 (offset 0)
# Ignoring wrong pointing object 662 65536 (offset 0)
# Ignoring wrong pointing object 666 65536 (offset 0)
# Ignoring wrong pointing object 670 65536 (offset 0)
# Ignoring wrong pointing object 674 65536 (offset 0)
# Ignoring wrong pointing object 678 65536 (offset 0)
# Ignoring wrong pointing object 682 65536 (offset 0)
# Ignoring wrong pointing object 686 65536 (offset 0)
# Ignoring wrong pointing object 690 65536 (offset 0)
# Ignoring wrong pointing object 694 65536 (offset 0)
# Ignoring wrong pointing object 698 65536 (offset 0)
# Ignoring wrong pointing object 702 65536 (offset 0)
# Ignoring wrong pointing object 706 65536 (offset 0)
# Ignoring wrong pointing object 710 65536 (offset 0)
# Ignoring wrong pointing object 714 65536 (offset 0)
# Ignoring wrong pointing object 718 65536 (offset 0)
# Ignoring wrong pointing object 722 65536 (offset 0)
# Ignoring wrong pointing object 726 65536 (offset 0)
# Ignoring wrong pointing object 730 65536 (offset 0)
# Ignoring wrong pointing object 734 65536 (offset 0)
# Ignoring wrong pointing object 738 65536 (offset 0)
# Ignoring wrong pointing object 742 65536 (offset 0)
# Ignoring wrong pointing object 746 65536 (offset 0)
# Ignoring wrong pointing object 750 65536 (offset 0)
# Ignoring wrong pointing object 754 65536 (offset 0)
# Ignoring wrong pointing object 758 65536 (offset 0)
# Ignoring wrong pointing object 762 65536 (offset 0)
# Ignoring wrong pointing object 766 65536 (offset 0)
# Ignoring wrong pointing object 770 65536 (offset 0)
# Ignoring wrong pointing object 774 65536 (offset 0)
# Ignoring wrong pointing object 778 65536 (offset 0)
# Ignoring wrong pointing object 782 65536 (offset 0)
# Ignoring wrong pointing object 787 65536 (offset 0)
# Ignoring wrong pointing object 792 65536 (offset 0)
# Ignoring wrong pointing object 796 65536 (offset 0)
# Ignoring wrong pointing object 800 65536 (offset 0)
# Ignoring wrong pointing object 804 65536 (offset 0)
# Ignoring wrong pointing object 808 65536 (offset 0)
# Ignoring wrong pointing object 812 65536 (offset 0)
# Ignoring wrong pointing object 816 65536 (offset 0)
# Ignoring wrong pointing object 820 65536 (offset 0)
# Ignoring wrong pointing object 824 65536 (offset 0)
# Ignoring wrong pointing object 828 65536 (offset 0)
# Ignoring wrong pointing object 832 65536 (offset 0)
# Ignoring wrong pointing object 836 65536 (offset 0)
# Ignoring wrong pointing object 840 65536 (offset 0)
# Ignoring wrong pointing object 844 65536 (offset 0)
# Ignoring wrong pointing object 848 65536 (offset 0)
# Ignoring wrong pointing object 852 65536 (offset 0)
# Ignoring wrong pointing object 868 65536 (offset 0)
# Ignoring wrong pointing object 872 65536 (offset 0)
# Ignoring wrong pointing object 876 65536 (offset 0)
# Ignoring wrong pointing object 881 65536 (offset 0)
# Ignoring wrong pointing object 886 65536 (offset 0)
# Ignoring wrong pointing object 890 65536 (offset 0)
# Ignoring wrong pointing object 901 65536 (offset 0)
# Ignoring wrong pointing object 905 65536 (offset 0)
# Ignoring wrong pointing object 909 65536 (offset 0)
# Ignoring wrong pointing object 913 65536 (offset 0)
# Ignoring wrong pointing object 917 65536 (offset 0)
# Ignoring wrong pointing object 921 65536 (offset 0)
# Ignoring wrong pointing object 925 65536 (offset 0)
# Ignoring wrong pointing object 929 65536 (offset 0)
# Ignoring wrong pointing object 933 65536 (offset 0)
# Ignoring wrong pointing object 937 65536 (offset 0)
# Ignoring wrong pointing object 941 65536 (offset 0)
# Ignoring wrong pointing object 945 65536 (offset 0)
# Ignoring wrong pointing object 949 65536 (offset 0)
# Ignoring wrong pointing object 953 65536 (offset 0)
# Ignoring wrong pointing object 957 65536 (offset 0)
# Ignoring wrong pointing object 961 65536 (offset 0)
# Ignoring wrong pointing object 965 65536 (offset 0)
# Ignoring wrong pointing object 969 65536 (offset 0)
# Ignoring wrong pointing object 973 65536 (offset 0)
# Ignoring wrong pointing object 977 65536 (offset 0)
# Ignoring wrong pointing object 981 65536 (offset 0)
# Ignoring wrong pointing object 985 65536 (offset 0)
# Ignoring wrong pointing object 989 65536 (offset 0)
# Ignoring wrong pointing object 993 65536 (offset 0)
# Ignoring wrong pointing object 997 65536 (offset 0)
# Ignoring wrong pointing object 1001 65536 (offset 0)
# Ignoring wrong pointing object 1005 65536 (offset 0)
# Ignoring wrong pointing object 1009 65536 (offset 0)
# Ignoring wrong pointing object 1013 65536 (offset 0)
# Ignoring wrong pointing object 1017 65536 (offset 0)
# Ignoring wrong pointing object 1021 65536 (offset 0)
# Ignoring wrong pointing object 1025 65536 (offset 0)
# Ignoring wrong pointing object 1029 65536 (offset 0)
# Ignoring wrong pointing object 1033 65536 (offset 0)
# Ignoring wrong pointing object 1037 65536 (offset 0)
# Ignoring wrong pointing object 1041 65536 (offset 0)
# Ignoring wrong pointing object 1045 65536 (offset 0)
# Ignoring wrong pointing object 1049 65536 (offset 0)
# Ignoring wrong pointing object 1053 65536 (offset 0)
# Ignoring wrong pointing object 1057 65536 (offset 0)
# Ignoring wrong pointing object 1061 65536 (offset 0)
# Ignoring wrong pointing object 1065 65536 (offset 0)
# Ignoring wrong pointing object 1069 65536 (offset 0)
# Ignoring wrong pointing object 1073 65536 (offset 0)
# Ignoring wrong pointing object 1077 65536 (offset 0)
# Ignoring wrong pointing object 1081 65536 (offset 0)
# Ignoring wrong pointing object 1085 65536 (offset 0)
# Ignoring wrong pointing object 1089 65536 (offset 0)
# Ignoring wrong pointing object 1093 65536 (offset 0)
# Ignoring wrong pointing object 1097 65536 (offset 0)
# Ignoring wrong pointing object 1101 65536 (offset 0)
# Ignoring wrong pointing object 1105 65536 (offset 0)
# Ignoring wrong pointing object 1109 65536 (offset 0)
# Ignoring wrong pointing object 1113 65536 (offset 0)
# Ignoring wrong pointing object 1117 65536 (offset 0)
# Ignoring wrong pointing object 1122 65536 (offset 0)
# Ignoring wrong pointing object 1126 65536 (offset 0)
# Ignoring wrong pointing object 1130 65536 (offset 0)
# Ignoring wrong pointing object 1134 65536 (offset 0)
# Ignoring wrong pointing object 1138 65536 (offset 0)
# Ignoring wrong pointing object 1143 65536 (offset 0)
# Ignoring wrong pointing object 1147 65536 (offset 0)
# Ignoring wrong pointing object 1151 65536 (offset 0)
# Ignoring wrong pointing object 1155 65536 (offset 0)
# Ignoring wrong pointing object 1159 65536 (offset 0)
# Ignoring wrong pointing object 1163 65536 (offset 0)
# Ignoring wrong pointing object 1167 65536 (offset 0)
# Ignoring wrong pointing object 1171 65536 (offset 0)
# Ignoring wrong pointing object 1175 65536 (offset 0)
# Ignoring wrong pointing object 1179 65536 (offset 0)
# Ignoring wrong pointing object 1183 65536 (offset 0)
# Ignoring wrong pointing object 1187 65536 (offset 0)
# Ignoring wrong pointing object 1191 65536 (offset 0)
# Ignoring wrong pointing object 1195 65536 (offset 0)
# Ignoring wrong pointing object 1199 65536 (offset 0)
# Ignoring wrong pointing object 1203 65536 (offset 0)
# Ignoring wrong pointing object 1207 65536 (offset 0)
# Ignoring wrong pointing object 1211 65536 (offset 0)
# Ignoring wrong pointing object 1215 65536 (offset 0)
# Ignoring wrong pointing object 1219 65536 (offset 0)
# Ignoring wrong pointing object 1223 65536 (offset 0)
# Ignoring wrong pointing object 1227 65536 (offset 0)
# Ignoring wrong pointing object 1231 65536 (offset 0)
# Ignoring wrong pointing object 1235 65536 (offset 0)
# Ignoring wrong pointing object 1239 65536 (offset 0)
# Ignoring wrong pointing object 1243 65536 (offset 0)
# Ignoring wrong pointing object 1247 65536 (offset 0)
# Ignoring wrong pointing object 1251 65536 (offset 0)
# Ignoring wrong pointing object 1255 65536 (offset 0)
# Ignoring wrong pointing object 1259 65536 (offset 0)
# Ignoring wrong pointing object 1263 65536 (offset 0)
# Ignoring wrong pointing object 1267 65536 (offset 0)
# Ignoring wrong pointing object 1271 65536 (offset 0)
# Ignoring wrong pointing object 1275 65536 (offset 0)
# Ignoring wrong pointing object 1280 65536 (offset 0)
# Ignoring wrong pointing object 1284 65536 (offset 0)
# Ignoring wrong pointing object 1289 65536 (offset 0)
# Ignoring wrong pointing object 1293 65536 (offset 0)
# Ignoring wrong pointing object 1297 65536 (offset 0)
# Ignoring wrong pointing object 1301 65536 (offset 0)
# Ignoring wrong pointing object 1305 65536 (offset 0)
# Ignoring wrong pointing object 1309 65536 (offset 0)
# Ignoring wrong pointing object 1313 65536 (offset 0)
# Ignoring wrong pointing object 1317 65536 (offset 0)
# Ignoring wrong pointing object 1321 65536 (offset 0)
# Ignoring wrong pointing object 1332 65536 (offset 0)
# Ignoring wrong pointing object 1336 65536 (offset 0)
# Ignoring wrong pointing object 1340 65536 (offset 0)
# Ignoring wrong pointing object 1344 65536 (offset 0)
# Ignoring wrong pointing object 1348 65536 (offset 0)
# Ignoring wrong pointing object 1352 65536 (offset 0)
# Ignoring wrong pointing object 1356 65536 (offset 0)
# Ignoring wrong pointing object 1361 65536 (offset 0)
# Ignoring wrong pointing object 1366 65536 (offset 0)
# Ignoring wrong pointing object 1370 65536 (offset 0)
# Ignoring wrong pointing object 1374 65536 (offset 0)
# Ignoring wrong pointing object 1378 65536 (offset 0)
# Ignoring wrong pointing object 1382 65536 (offset 0)
# Ignoring wrong pointing object 1386 65536 (offset 0)
# Ignoring wrong pointing object 1390 65536 (offset 0)
# Ignoring wrong pointing object 1394 65536 (offset 0)
# Ignoring wrong pointing object 1398 65536 (offset 0)
# Ignoring wrong pointing object 1402 65536 (offset 0)
# Ignoring wrong pointing object 1406 65536 (offset 0)
# Ignoring wrong pointing object 1410 65536 (offset 0)
# Ignoring wrong pointing object 1415 65536 (offset 0)
# Ignoring wrong pointing object 1419 65536 (offset 0)
# Ignoring wrong pointing object 1423 65536 (offset 0)
# Ignoring wrong pointing object 1427 65536 (offset 0)
# Ignoring wrong pointing object 1431 65536 (offset 0)
# Ignoring wrong pointing object 1435 65536 (offset 0)
# Ignoring wrong pointing object 1440 65536 (offset 0)
# Ignoring wrong pointing object 1444 65536 (offset 0)
# Ignoring wrong pointing object 1448 65536 (offset 0)
# Ignoring wrong pointing object 1452 65536 (offset 0)
# Ignoring wrong pointing object 1456 65536 (offset 0)
# Ignoring wrong pointing object 1460 65536 (offset 0)
# Ignoring wrong pointing object 1464 65536 (offset 0)
# Ignoring wrong pointing object 1468 65536 (offset 0)
# Ignoring wrong pointing object 1472 65536 (offset 0)
# Ignoring wrong pointing object 1476 65536 (offset 0)
# Ignoring wrong pointing object 1480 65536 (offset 0)
# Ignoring wrong pointing object 1484 65536 (offset 0)
# Ignoring wrong pointing object 1489 65536 (offset 0)
# Ignoring wrong pointing object 1493 65536 (offset 0)
# Ignoring wrong pointing object 1497 65536 (offset 0)
# Ignoring wrong pointing object 1501 65536 (offset 0)
# Ignoring wrong pointing object 1505 65536 (offset 0)
# Ignoring wrong pointing object 1509 65536 (offset 0)
# Ignoring wrong pointing object 1513 65536 (offset 0)
# Ignoring wrong pointing object 1518 65536 (offset 0)
# Ignoring wrong pointing object 1522 65536 (offset 0)
# Ignoring wrong pointing object 1526 65536 (offset 0)
# Ignoring wrong pointing object 1530 65536 (offset 0)
# Ignoring wrong pointing object 1534 65536 (offset 0)
# Ignoring wrong pointing object 1538 65536 (offset 0)
# Ignoring wrong pointing object 1542 65536 (offset 0)
# Ignoring wrong pointing object 1546 65536 (offset 0)
# Ignoring wrong pointing object 1550 65536 (offset 0)
# Ignoring wrong pointing object 1554 65536 (offset 0)
# Ignoring wrong pointing object 1558 65536 (offset 0)
# Ignoring wrong pointing object 1562 65536 (offset 0)
# Ignoring wrong pointing object 1566 65536 (offset 0)
# Ignoring wrong pointing object 1570 65536 (offset 0)
# Ignoring wrong pointing object 1574 65536 (offset 0)
# Ignoring wrong pointing object 1578 65536 (offset 0)
# Ignoring wrong pointing object 1583 65536 (offset 0)
# Ignoring wrong pointing object 1587 65536 (offset 0)
# Ignoring wrong pointing object 1591 65536 (offset 0)
# Ignoring wrong pointing object 1595 65536 (offset 0)
# Ignoring wrong pointing object 1599 65536 (offset 0)
# Ignoring wrong pointing object 1603 65536 (offset 0)
# Ignoring wrong pointing object 1614 65536 (offset 0)
# Ignoring wrong pointing object 1618 65536 (offset 0)
# Ignoring wrong pointing object 1622 65536 (offset 0)
# Ignoring wrong pointing object 1626 65536 (offset 0)
# Ignoring wrong pointing object 1630 65536 (offset 0)
# Ignoring wrong pointing object 1634 65536 (offset 0)
# Ignoring wrong pointing object 1638 65536 (offset 0)
# Ignoring wrong pointing object 1642 65536 (offset 0)
# Ignoring wrong pointing object 1646 65536 (offset 0)
# Ignoring wrong pointing object 1650 65536 (offset 0)
# Ignoring wrong pointing object 1654 65536 (offset 0)
# Ignoring wrong pointing object 1658 65536 (offset 0)
# Ignoring wrong pointing object 1662 65536 (offset 0)
# Ignoring wrong pointing object 1666 65536 (offset 0)
# Ignoring wrong pointing object 1670 65536 (offset 0)
# Ignoring wrong pointing object 1674 65536 (offset 0)
# Ignoring wrong pointing object 1678 65536 (offset 0)
# Ignoring wrong pointing object 1682 65536 (offset 0)
# Ignoring wrong pointing object 1686 65536 (offset 0)
# Ignoring wrong pointing object 1690 65536 (offset 0)
# Ignoring wrong pointing object 1694 65536 (offset 0)
# Ignoring wrong pointing object 1698 65536 (offset 0)
# Ignoring wrong pointing object 1702 65536 (offset 0)
# Ignoring wrong pointing object 1706 65536 (offset 0)
# Ignoring wrong pointing object 1710 65536 (offset 0)
# Ignoring wrong pointing object 1714 65536 (offset 0)
# Ignoring wrong pointing object 1718 65536 (offset 0)
# Ignoring wrong pointing object 1722 65536 (offset 0)
# Ignoring wrong pointing object 1741 65536 (offset 0)
# Ignoring wrong pointing object 1745 65536 (offset 0)
# Ignoring wrong pointing object 1749 65536 (offset 0)
# Ignoring wrong pointing object 1754 65536 (offset 0)
# Ignoring wrong pointing object 1759 65536 (offset 0)
# Ignoring wrong pointing object 1764 65536 (offset 0)
# Ignoring wrong pointing object 1769 65536 (offset 0)
# Ignoring wrong pointing object 1773 65536 (offset 0)
# Ignoring wrong pointing object 1778 65536 (offset 0)
# Ignoring wrong pointing object 1782 65536 (offset 0)
# Ignoring wrong pointing object 1786 65536 (offset 0)
# Ignoring wrong pointing object 1790 65536 (offset 0)
# Ignoring wrong pointing object 1794 65536 (offset 0)
# Ignoring wrong pointing object 1798 65536 (offset 0)
# Ignoring wrong pointing object 1802 65536 (offset 0)
# Ignoring wrong pointing object 1807 65536 (offset 0)
# Ignoring wrong pointing object 1818 65536 (offset 0)
# Ignoring wrong pointing object 1822 65536 (offset 0)
# Ignoring wrong pointing object 1826 65536 (offset 0)
# Ignoring wrong pointing object 1830 65536 (offset 0)
# Ignoring wrong pointing object 1834 65536 (offset 0)
# Ignoring wrong pointing object 1838 65536 (offset 0)
# Ignoring wrong pointing object 1842 65536 (offset 0)
# Ignoring wrong pointing object 1846 65536 (offset 0)
# Ignoring wrong pointing object 1850 65536 (offset 0)
# Ignoring wrong pointing object 1854 65536 (offset 0)
# Ignoring wrong pointing object 1858 65536 (offset 0)
# Ignoring wrong pointing object 1862 65536 (offset 0)
# Ignoring wrong pointing object 1868 65536 (offset 0)
# Ignoring wrong pointing object 1872 65536 (offset 0)
# Ignoring wrong pointing object 1876 65536 (offset 0)
# Ignoring wrong pointing object 1880 65536 (offset 0)
# Ignoring wrong pointing object 1884 65536 (offset 0)
# Ignoring wrong pointing object 1888 65536 (offset 0)
# Ignoring wrong pointing object 1899 65536 (offset 0)
# Ignoring wrong pointing object 1903 65536 (offset 0)
# Ignoring wrong pointing object 1907 65536 (offset 0)
# Ignoring wrong pointing object 1912 65536 (offset 0)
# Ignoring wrong pointing object 1916 65536 (offset 0)
# Ignoring wrong pointing object 1920 65536 (offset 0)
# Ignoring wrong pointing object 1924 65536 (offset 0)
# Ignoring wrong pointing object 1928 65536 (offset 0)
# Ignoring wrong pointing object 1932 65536 (offset 0)
# Ignoring wrong pointing object 1936 65536 (offset 0)
# Ignoring wrong pointing object 1950 65536 (offset 0)
# Ignoring wrong pointing object 1954 65536 (offset 0)
# Ignoring wrong pointing object 1961 65536 (offset 0)
# Advanced encoding /KSC-EUC-H not implemented yet
# Advanced encoding /KSC-EUC-H not implemented yet
# Advanced encoding /KSC-EUC-H not implemented yet
# Advanced encoding /KSC-EUC-H not implemented yet
# 총 960 페이지의 문서가 로드되었습니다.
# 첫 번째 문서의 일부 내용:

# %%
print(f"첫 번째 문서의 일부 내용:\n{docs[250].page_content[:200]}")
print(f"첫 번째 문서의 일부 내용:\n{docs[510].page_content[:200]}")
print(f"두 번째 문서의 일부 내용:\n{docs[850].page_content[:200]}")
print(f"두 번째 문서의 일부 내용:\n{docs[900].page_content[:200]}")
# Out:
# 첫 번째 문서의 일부 내용:
# 249김정수 (롯) 49 김우열 (O) 56
# 이종도 (M) 48 윤동균 (O) 54
# 윤동균 (O) 47 김용희 (롯) 52
# 김준환 (해) 45 신경식 (O) 50
# 1984 --------------- 1985 ---------------
# 이만수 (삼) 80 이만수 (삼) 87
# 이광은 (M) 68 김성한 (해) 75
# 김용철 (롯) 67 장효조 (삼) 65
# 김
# 첫 번째 문서의 일부 내용:
# 509연도 참가 구단총
# 경기수팀당
# 경기수팀간
# 경기수시즌구분경기제도 우승팀 비고
# 1992(8개 구단)
# OB 베어스해태 타이거즈
# 삼성 라이온즈
# 롯데 자이언츠빙그레 이글스
# 태평양 돌핀스
# LG 트윈스
# 쌍방울 레이더스504 126 18
# 〃 〃정규시즌1위-빙그레2위-해태
# 3위-롯데
# 4위-삼성준PO-롯데
# PO 진출
# PO-롯데시리즈 진출
# 한국시리즈
# -롯데
# 1993
# 〃50
# 두 번째 문서의 일부 내용:
# 홈․런․기․록
# 325연도별 10홈런 선점 선수
# <일자 기준 / 선점과 최소 경기 다른 경우 별도 표시>
# 연도 선수명(팀) 일자 개인 경기수 팀 경기수 달성당시 연령
# 1982 김우열(O) 5.23 22 24 3 2 세   8 개 월  1 4 일
# 1983 김봉연(해) 5.21 25 25 3 1 세   4 개 월   8 일
# 1984 이만수(삼) 5.10 24 2
# 두 번째 문서의 일부 내용:
# 끝․내․기․기․록
# 375구분 일자 대진 구장 이닝 점수 아웃 주자 타자명 투수명 볼카운트
# 4 9 2 0 1 4 . 8 .2 9 넥   센  -  한   화 대  전 1 09-9
# 9-101사
# 123  정 범 모  송 신 영 3  -  1
# 5 0 2 0 1 5 . 5 .1 7 넥   센  -  한   화 대  전 1 06-6
# 6-72사
# 123  강 경 학  배

# %% [markdown]
# ## 3. 텍스트 분할 (Split Documents)
#
# 로드된 문서를 작은 청크(chunk)로 분할합니다.
# RecursiveCharacterTextSplitter를 사용합니다.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=700,
    chunk_overlap=100
)

splits = text_splitter.split_documents(docs)
print(f"총 {len(splits)} 개의 청크로 분할되었습니다.")
# Out:
# 총 3044 개의 청크로 분할되었습니다.

# %% [markdown]
# ## 4. 벡터 스토어 생성 (Create Vector Store)
#
# FAISS를 사용하여 벡터 스토어를 생성합니다.

# %%
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings

# Embeddings 모델 초기화
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

#  첫 배치만 from_documents로 인덱스 생성
FIRST_BATCH_SIZE = 30
first_batch = splits[:FIRST_BATCH_SIZE]

vectorstore = FAISS.from_documents(first_batch, embeddings)
print("초기 vectorstore 생성 완료")

#  나머지 문서들을 add_documents로 안전하게 추가
BATCH_SIZE = 50

for i in range(FIRST_BATCH_SIZE, len(splits), BATCH_SIZE):
    batch = splits[i : i + BATCH_SIZE]
    print(f"배치 추가 중: {i} ~ {i+len(batch)}")
    vectorstore.add_documents(batch)

print("모든 청크가 벡터스토어에 성공적으로 추가됨")

# 저장
vectorstore.save_local("./faiss_index")
print("FAISS index 저장 완료")
# Out:
# 초기 vectorstore 생성 완료
# 배치 추가 중: 30 ~ 80
# 배치 추가 중: 80 ~ 130
# 배치 추가 중: 130 ~ 180
# 배치 추가 중: 180 ~ 230
# 배치 추가 중: 230 ~ 280
# 배치 추가 중: 280 ~ 330
# 배치 추가 중: 330 ~ 380
# 배치 추가 중: 380 ~ 430
# 배치 추가 중: 430 ~ 480
# 배치 추가 중: 480 ~ 530
# 배치 추가 중: 530 ~ 580
# 배치 추가 중: 580 ~ 630
# 배치 추가 중: 630 ~ 680
# 배치 추가 중: 680 ~ 730
# 배치 추가 중: 730 ~ 780
# 배치 추가 중: 780 ~ 830
# 배치 추가 중: 830 ~ 880
# 배치 추가 중: 880 ~ 930
# 배치 추가 중: 930 ~ 980
# 배치 추가 중: 980 ~ 1030
# 배치 추가 중: 1030 ~ 1080
# 배치 추가 중: 1080 ~ 1130
# 배치 추가 중: 1130 ~ 1180
# 배치 추가 중: 1180 ~ 1230
# 배치 추가 중: 1230 ~ 1280
# 배치 추가 중: 1280 ~ 1330
# 배치 추가 중: 1330 ~ 1380
# 배치 추가 중: 1380 ~ 1430
# 배치 추가 중: 1430 ~ 1480
# 배치 추가 중: 1480 ~ 1530
# 배치 추가 중: 1530 ~ 1580
# 배치 추가 중: 1580 ~ 1630
# 배치 추가 중: 1630 ~ 1680
# 배치 추가 중: 1680 ~ 1730
# 배치 추가 중: 1730 ~ 1780
# 배치 추가 중: 1780 ~ 1830
# 배치 추가 중: 1830 ~ 1880
# 배치 추가 중: 1880 ~ 1930
# 배치 추가 중: 1930 ~ 1980
# 배치 추가 중: 1980 ~ 2030
# 배치 추가 중: 2030 ~ 2080
# 배치 추가 중: 2080 ~ 2130
# 배치 추가 중: 2130 ~ 2180
# 배치 추가 중: 2180 ~ 2230
# 배치 추가 중: 2230 ~ 2280
# 배치 추가 중: 2280 ~ 2330
# 배치 추가 중: 2330 ~ 2380
# 배치 추가 중: 2380 ~ 2430
# 배치 추가 중: 2430 ~ 2480
# 배치 추가 중: 2480 ~ 2530
# 배치 추가 중: 2530 ~ 2580
# 배치 추가 중: 2580 ~ 2630
# 배치 추가 중: 2630 ~ 2680
# 배치 추가 중: 2680 ~ 2730
# 배치 추가 중: 2730 ~ 2780
# 배치 추가 중: 2780 ~ 2830
# 배치 추가 중: 2830 ~ 2880
# 배치 추가 중: 2880 ~ 2930
# 배치 추가 중: 2930 ~ 2980
# 배치 추가 중: 2980 ~ 3030
# 배치 추가 중: 3030 ~ 3044
# 모든 청크가 벡터스토어에 성공적으로 추가됨
# FAISS index 저장 완료

# %% [markdown]
# ## 5. 검색기(Retriever) 설정 및 확인
#
# Retriever를 설정하고, 실제 질문에 대해 어떤 문서가 검색되는지 확인합니다.

# %%
# 검색기 설정 (k=5, similarity)
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}
)

# 검색기 작동 확인
print("검색기 작동 확인!!")
docs = retriever.invoke("700승을 기록한 감독은 누구인가요")
print(f"검색된 문서 개수: {len(docs)}")
for i, doc in enumerate(docs):
    print(f"\n[문서 {i+1}]")
    print(doc.page_content[:200])
# Out:
# 검색기 작동 확인!!
# 검색된 문서 개수: 5
#
# [문서 1]
# 기․타․기․록
# 424
# 감독 700승
# ■ 1993년 9월 12일 해태 김응용, 빙그레 김영덕 감독은 같은 날 700승을 달성했으며, 김영덕 감독은 1,1 96경기로 역
# 대 최소 경기 700승 기록을 가지고 있다. 이후 감독 700승을 달성한 감독은 김성근, 강병철, 김인식, 김재박 , 김경문
# 감독이 있으며, 2024년에는 2시즌 만에 현역으로 복귀한 김태형
#
# [문서 2]
# 8 2024. 8.31 김태형(롯) 1,269 두  산 잠 실 56세 11개월 19일
# 감독 1,000승
# ■ 해태 시절 통산 9차례나 팀을 우승으로 이끌었던 김응용 감독은 1998년 6월 7일 무등에서
# 삼성을 상대로 누구도 달성하지 못한 감독 1,000승이라는 대기록을 세웠다. 통산 1,554승을
# 기록한 김응용 감독의 뒤를 이어 김성근 감독이 1,388승
#
# [문서 3]
# (야쿠르트)이 기록한 3,248경기이다.
# 구분 감독명(팀) 일자 상대팀(구장) 승 패 무 달성당시 연령
# 1 김응용(삼) 2003. 9. 8 현  대(수원) 1,382 1,063 55 61세 11개월 24일
# 2 김성근(한) 2016. 5. 1 삼  성(대전) 1,313 1,130 57 73세  4개월 18일
# 감독 500승
# 구분 일자 감독명(팀) 경기수 상대팀
#
# [문서 4]
# 117연도별(구단별) 감독 ․코치 및 선수 등록 현황
# ※ 2.1 소속선수 등록일 기준
# 구단 1982 1983 1984 1985 1986 1987 1988 1989
# 감독 코치 선수 소계 감독 코치 선수 소계 감독 코치 선수 소계 감독 코치 선수 소계 감독 코치 선수 소계 감독 코치 선수 소계 감독 코치 선수 소계 감독 코치 선수 소계
# 해  태 1 2 22 2
#
# [문서 5]
# 기․타․기․록
# 423감독 2,500경기 출장
# ■ 삼성 김응용 감독은 2003년 9월 8일 수원 현대전에서 지난 2000년 프로 최초의 감독 2,000경기 출장에  이어 2,500
# 경기 출장이라는 또 하나의 대업을 달성했다. 1983년 해태 사령탑으로 프로야구 지도자의 첫 발을 내디딘 김응용 감
# 독은 이후 18년 동안 한 팀에서만 무려 2,122경기에 출장했

# %% [markdown]
# ## 6. 프롬프트(Prompt) 설정 및 확인
#
# RAG에 사용할 프롬프트를 로드하고 확인합니다.

# %%
from langchain import hub

# 프롬프트 로드
prompt = hub.pull("rlm/rag-prompt")

# 프롬프트 내용 출력
print("\n프롬프트 템플릿:")
print(prompt.messages[0].prompt.template)
# Out:
# 프롬프트 템플릿:
# You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
# Question: {question}
# Context: {context}
# Answer:

# %% [markdown]
# ## 7. RAG 체인 생성 (Create RAG Chain)
#
# 문서 검색기(Retriever), 프롬프트, LLM을 연결하여 RAG 체인을 만듭니다.

# %%
from langchain import hub
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI

# LLM 설정 (gpt-5.1)
llm = ChatOpenAI(model_name="gpt-5.1", temperature=0)

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# RAG 체인 구성
rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# ## 8. 질문하기
#
# KBO 규정이나 기록에 대한 질문을 던져봅니다.

# %%
# 질문
question = "40 세이브를 최초로 달성한 선수는 누구인가요"
# question = "시즌 최다 세이브를 달성한 선수는 누구인가요. 그리고 총 몇세이브를 달성했나요"
# ㅂuestion = "700승을 기록한 감독은 누구인가요"


# 답변 생성
response = rag_chain.invoke(question)


print(f"질문: {question}\n")
print(f"답변: {response}")
# Out:
# 질문: 40 세이브를 최초로 달성한 선수는 누구인가요
#
# 답변: KBO 리그에서 한 시즌 40세이브를 최초로 달성한 선수는 태평양 돌핀스의 정명원입니다.
